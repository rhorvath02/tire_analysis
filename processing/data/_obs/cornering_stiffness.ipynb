# %%
import matplotlib.pyplot as plt

# %%
#Round 4
tires = {"Hoosier 18.0 x 6.0 - 10 R25B": [[350, 118, 0], [150, 108, 0], [50, 61, 0], [250, 125, 0], [100, 94, 0], [350, 116, 2], [150, 108, 2], [50, 57, 2], [250, 123, 2], [100, 87, 2], [350, 111, 4], [150, 99, 4], [50, 43, 4], [250, 118, 4], [100, 76, 4], [350, 115, 1], [150, 109, 1], [50, 61, 1], [250, 122, 1], [100, 91, 1], [350, 112, 3], [150, 104, 3], [50, 50, 3], [250, 119, 3], [100, 82, 3]]}
"Hoosier 6.0 / 18.0 - 10 LCO"
for tire in tires.values():
    for item in tire:
        if item[2] == 0:
            plt.scatter(1, item[1] / item[0])
    

plt.show()
